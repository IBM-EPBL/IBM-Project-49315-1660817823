# %%
test_dir=r'D:\Studies\IBM\Project\Dataset_Plant_Disease\fruit-dataset\fruit-dataset\test'

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model

# %%
model=load_model(r'D:\Studies\IBM\Project\Fruit.h5')

# %%
test_gen=ImageDataGenerator(rescale=1).flow_from_directory(test_dir,target_size=(128,128),batch_size=32,class_mode='categorical')
# Out:
# Found 1686 images belonging to 6 classes.

# %%
img=image.load_img(r'D:\Studies\IBM\Project\Dataset_Plant_Disease\fruit-dataset\fruit-dataset\test\Peach___Bacterial_spot\0e37dd9c-c73d-403b-81c9-60c108607d1a___Rutg._Bact.S 1610.JPG',target_size=(128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
pred=model.predict(x)
list=['Apple___Black_rot','Apple___healthy','Corn_(maize)___healthy','Corn_(maize)___Northern_Leaf_Blight','Peach___Bacterial_spot','Peach___healthy']
list[np.argmax(pred)]
# Out:
# 1/1 [==============================] - 0s 225ms/step
# 'Peach___Bacterial_spot'

# %%
model.evaluate(test_gen,steps=50)
# Out:
# 50/50 [==============================] - 7s 139ms/step - loss: 801.1005 - accuracy: 0.6219
# [801.1004638671875, 0.621874988079071]
