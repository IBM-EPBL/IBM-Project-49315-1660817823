# %%
test_dir=r'D:\Studies\IBM\Project\Dataset_Plant_Disease\veg-dataset\veg-dataset\test_set'

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model

# %%
model=load_model(r'D:\Studies\IBM\Project\Vegetable.h5')

# %%
test_gen=ImageDataGenerator(rescale=1).flow_from_directory(test_dir,target_size=(128,128),batch_size=32,class_mode='categorical')
# Out:
# Found 3416 images belonging to 9 classes.

# %%
img=image.load_img(r'D:\Studies\IBM\Project\Dataset_Plant_Disease\Veg-dataset\Veg-dataset\test_set\Tomato___Septoria_leaf_spot\c35001a9-bfcc-4233-95e5-b83d086e0435___Matt.S_CG 6740.JPG',target_size=(128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
pred=model.predict(x)
list=['Pepper,_bell___Bacterial_spot','Pepper,_bell___healthy','Potato___Early_blight','Potato___healthy','Potato___Late_blight','Tomato___Bacterial_spot','Tomato___Late_blight','Tomato___Leaf_Mold','Tomato___Septoria_leaf_spot']
list[np.argmax(pred)]
# Out:
# 1/1 [==============================] - 0s 286ms/step
# 'Tomato___Septoria_leaf_spot'

# %%
model.evaluate(test_gen,steps=50)
# Out:
# 50/50 [==============================] - 7s 138ms/step - loss: 2635.3245 - accuracy: 0.2612
# [2635.324462890625, 0.26124998927116394]
